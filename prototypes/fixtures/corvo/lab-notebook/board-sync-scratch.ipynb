// %% [markdown]
// # Board sync scratch
// Unconverted working notes from the 2026-05-19 board sync.
// Deliberately left in .ipynb form: this folder's ingest ritual only
// accepts md/txt/json/csv, so a dry-run should skip this file with a
// dirty warning (per issue #64).
